# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA, ARMAResults

import sys
import seaborn as sns
import statsmodels
import statsmodels.stats.diagnostic as diag
from statsmodels.tsa.stattools import adfuller
from scipy.stats.mstats import normaltest
from pandas import datetime

from matplotlib.pyplot import acorr
plt.style.use('fivethirtyeight')
# %matplotlib inline
import random
def parser(x):
    year = random.randint(1990, 2000)
    month = random.randint(1, 12)
    day = random.randint(1, 28)
    return datetime(year, month, day)    
#Read the csv file and parse the date    
df = pd.read_csv('C:\DataScience\data_stocks.csv', header=0, parse_dates=[0], index_col=0,squeeze=True, date_parser=parser)
#df = pd.read_csv('C:\DataScience\data_stocks.csv')

df.head()
# Out:
#                 SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# DATE
# 1998-04-22  2363.6101     42.3300     143.6800     129.6300      82.040
# 1992-10-12  2364.1001     42.3600     143.7000     130.3200      82.080
# 2000-05-10  2362.6799     42.3100     143.6901     130.2250      82.030
# 1993-03-13  2364.3101     42.3700     143.6400     130.0729      82.000
# 1996-11-19  2364.8501     42.5378     143.6600     129.8800      82.035
#
#             NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  NASDAQ.AMAT  \
# DATE
# 1998-04-22    102.2300      85.2200       59.760       121.52        38.99
# 1992-10-12    102.1400      85.6500       59.840       121.48        39.01
# 2000-05-10    102.2125      85.5100       59.795       121.93        38.91
# 1993-03-13    102.1400      85.4872       59.620       121.44        38.84
# 1996-11-19    102.0600      85.7001       59.620       121.60        38.93
#
# ...

# %%
#Stocks to forecast:
#1. NASDAQ.AAPL
#2. NASDAQ.ADP
#3. NASDAQ.CBOE
#4. NASDAQ.CSCO
#5. NASDAQ.EBAY
df.describe()
# Out:
#               SP500    NASDAQ.AAL   NASDAQ.AAPL  NASDAQ.ADBE    NASDAQ.ADI  \
# count  41266.000000  41266.000000  41266.000000  41266.00000  41266.000000
# mean    2421.537882     47.708346    150.453566    141.31793     79.446873
# std       39.557135      3.259377      6.236826      6.91674      2.000283
# min     2329.139900     40.830000    140.160000    128.24000     74.800000
# 25%     2390.860100     44.945400    144.640000    135.19500     78.030000
# 50%     2430.149900     48.360000    149.945000    142.26000     79.410000
# 75%     2448.820100     50.180000    155.065000    147.10000     80.580000
# max     2490.649900     54.475000    164.510000    155.33000     90.440000
#
#          NASDAQ.ADP   NASDAQ.ADSK   NASDAQ.AKAM   NASDAQ.ALXN   NASDAQ.AMAT  \
# count  41266.000000  41266.000000  41266.000000  41266.000000  41266.000000
# mean     103.480398    102.998608     50.894352    122.981163     43.291988
# ...

# %%
#Checking if any null values in values of the stock
df["NASDAQ.AAPL"]
df.isnull().values.any()
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# ...

# %%
#Plot the movement of stock of NASDAQ.AAPL
plt.figure(figsize=(15, 7))
plt.plot(df["NASDAQ.AAPL"])
plt.title('Movement of stocks (date wise)')
plt.grid(True)
plt.show()

# %%
series = df[["NASDAQ.AAPL"]]
series.describe()
# Dimensions of dataset
n = series.shape[0]
p = series.shape[1]
# Make data a numpy array
data = series.values
# Training and test data
train_start = 0
train_end = int(np.floor(0.8*n))
test_start = train_end
test_end = n
data_train = data[np.arange(train_start, train_end), :]
data_test = data[np.arange(test_start, test_end), :]

# %%
data_train.mean()
# show plots in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
series.plot()
plt.show()

# %%
#Auto correlate the plot to smoothen the time series pattern
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()

# %%
from pandas import DataFrame

#fit the model for the Stock movement of NASDAQ.AAPL

series = df[["NASDAQ.AAPL"]]
pd.to_datetime(series.index)
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())

# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:          D.NASDAQ.AAPL   No. Observations:                41265
# Model:                 ARIMA(5, 1, 0)   Log Likelihood               39230.690
# Method:                       css-mle   S.D. of innovations              0.094
# Date:                Tue, 01 Jan 2019   AIC                         -78447.380
# Time:                        22:34:36   BIC                         -78386.985
# Sample:                    06-03-1998   HQIC                        -78428.291
#                          - 03-26-1991
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0005      0.000      1.113      0.266      -0.000       0.001
# ar.L1.D.NASDAQ.AAPL    -0.0102      0.005     -2.082      0.037      -0.020      -0.001
# ...

# %%
#Forecast for the future values using the model
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=147.128863, expected=147.129900
# predicted=147.134310, expected=146.910000
# predicted=146.908469, expected=146.960000
# predicted=146.967670, expected=146.960000
# predicted=146.957288, expected=146.920000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-246c81af5501> in <module>()
#       7 for t in range(len(test)):
#       8     model = ARIMA(history, order=(5,1,0))
# ----> 9     model_fit = model.fit(disp=0)
#      10     output = model_fit.forecast()
#      11     yhat = output[0]
#
# C:\Anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1149                                            method, transparams, solver,
#    1150                                            maxiter, full_output, disp,
# ...

# %%
#fit the model for the Stock movement of NASDAQ.ADP
series = df[["NASDAQ.ADP"]]
series.describe()
#keep test data of 1903
# Dimensions of dataset
n = series.shape[0]
p = series.shape[1]
# Make data a numpy array
data = series.values
# Training and test data
train_start = 0
train_end = int(np.floor(0.8*n))
test_start = train_end
test_end = n
data_train = data[np.arange(train_start, train_end), :]
data_test = data[np.arange(test_start, test_end), :]
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()
from pandas import DataFrame

#fit the model for the Stock movement of NASDAQ.ADP
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-3261cdae9e63> in <module>()
#      16 data_test = data[np.arange(test_start, test_end), :]
#      17 from pandas.plotting import autocorrelation_plot
# ---> 18 autocorrelation_plot(series)
#      19 plt.show()
#      20 from pandas import DataFrame
#
# C:\Anaconda3\lib\site-packages\pandas\plotting\_misc.py in autocorrelation_plot(series, ax, **kwds)
#     557                 (data[h:] - mean)).sum() / float(n) / c0
#     558     x = np.arange(n) + 1
# --> 559     y = lmap(r, x)
#     560     z95 = 1.959963984540054
#     561     z99 = 2.5758293035489004
#
# C:\Anaconda3\lib\site-packages\pandas\compat\__init__.py in lmap(*args, **kwargs)
#     122
#     123     def lmap(*args, **kwargs):
# --> 124         return list(map(*args, **kwargs))
#     125
#     126     def lfilter(*args, **kwargs):
#
# ...

# %%
series = df[["NASDAQ.CBOE"]]
series.describe()
#keep test data of 1903
# Dimensions of dataset
n = series.shape[0]
p = series.shape[1]
# Make data a numpy array
data = series.values
# Training and test data
train_start = 0
train_end = int(np.floor(0.8*n))
test_start = train_end
test_end = n
data_train = data[np.arange(train_start, train_end), :]
data_test = data[np.arange(test_start, test_end), :]
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()
from pandas import DataFrame

#fit the model for the Stock movement ofNASDAQ.CBOE
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# %%
series = df[["NASDAQ.CSCO"]]
series.describe()

# Dimensions of dataset
n = series.shape[0]
p = series.shape[1]
# Make data a numpy array
data = series.values
# Training and test data
train_start = 0
train_end = int(np.floor(0.8*n))
test_start = train_end
test_end = n
data_train = data[np.arange(train_start, train_end), :]
data_test = data[np.arange(test_start, test_end), :]
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()
from pandas import DataFrame

#fit the model for the stick NASDAQ.CSCO
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()

# %%
series = df[["NASDAQ.EBAY"]]
series.describe()

# Dimensions of dataset
n = series.shape[0]
p = series.shape[1]
# Make data a numpy array
data = series.values
# Training and test data
train_start = 0
train_end = int(np.floor(0.8*n))
test_start = train_end
test_end = n
data_train = data[np.arange(train_start, train_end), :]
data_test = data[np.arange(test_start, test_end), :]
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()
from pandas import DataFrame

#fit the model for the stock NASDAQ.EBAY
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
