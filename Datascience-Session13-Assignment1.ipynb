# %%
#Read the following data set:https://archive.ics.uci.edu/ml/machine-learning-databases/adult/
#Rename the columns as per the description from this file:
#https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.names
import pandas as pd
colnames=["age","workclass","fnlwgt","education","education_num","marital_status","occupation",
                       "relationship","race","sex","capital_gain",
                        "capital_loss","hours_per_week","native_country","prediction"]
adultdf=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",names=colnames)
adultdf.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'prediction'],
#       dtype='object')

# %%
#1.load the dataframe to sql table
from sqlalchemy import create_engine
engine = create_engine('sqlite:///mydatabase.db')
adultdf.to_sql(name='adultnamestbl', con=engine)

# %%
#Basic two update queries
from sqlalchemy.sql import select
#Update  nativecountry to United States, where age is 50
engine.execute("update adultnamestbl set native_country='United-States' where age == 50")
engine.execute("SELECT native_country FROM adultnamestbl  where age == 50").fetchall()
#Update  nativecountry to United States, where age is 50
engine.execute("update adultnamestbl set hours_per_week=10 where age == 50")
engine.execute("SELECT hours_per_week FROM adultnamestbl  where age == 50").fetchall()
# Out:
# [(10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
#  (10,),
# ...

# %%
#Write two delete queries
engine.execute("delete from adultnamestbl  where age == 50")
engine.execute("delete frOM adultnamestbl  where hours_per_week  == 10")
engine.execute("SELECT hours_per_week FROM adultnamestbl  where age == 50").fetchall()
# Out:
# []

# %%
#Write two filter queries
result = engine.execute("SELECT hours_per_week FROM adultnamestbl  where age == 10").fetchall()
print(result)
engine.execute("SELECT * FROM adultnamestbl  where age == 20").fetchall()
# Out:
# []
# [(31, 20, ' Private', 266015, ' Some-college', 10, ' Never-married', ' Sales', ' Own-child', ' Black', ' Male', 0, 0, 44, ' United-States', ' <=50K'),
#  (103, 20, ' Private', 188300, ' Some-college', 10, ' Never-married', ' Tech-support', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K'),
#  (126, 20, ' Private', 111697, ' Some-college', 10, ' Never-married', ' Adm-clerical', ' Own-child', ' White', ' Female', 0, 1719, 28, ' United-States', ' <=50K'),
#  (138, 20, ' Private', 34310, ' Some-college', 10, ' Never-married', ' Sales', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K'),
#  (243, 20, ' ?', 119156, ' Some-college', 10, ' Never-married', ' ?', ' Own-child', ' White', ' Male', 0, 0, 20, ' United-States', ' <=50K'),
#  (256, 20, ' Private', 117789, ' HS-grad', 9, ' Never-married', ' Other-service', ' Own-child', ' White', ' Female', 0, 0, 40, ' United-States', ' <=50K'),
# ...

# %%
#Write two function queries
result = engine.execute("SELECT max(hours_per_week),native_country as max_hours FROM adultnamestbl  group by native_country").fetchall()
print(result)
engine.execute("SELECT sum(capital_gain),native_country as totalcapitalgain FROM adultnamestbl  group by native_country").fetchall()
# Out:
# [(99, ' ?'), (50, ' Cambodia'), (72, ' Canada'), (60, ' China'), (60, ' Columbia'), (70, ' Cuba'), (98, ' Dominican-Republic'), (66, ' Ecuador'), (60, ' El-Salvador'), (99, ' England'), (99, ' France'), (70, ' Germany'), (75, ' Greece'), (60, ' Guatemala'), (75, ' Haiti'), (40, ' Holand-Netherlands'), (60, ' Honduras'), (65, ' Hong'), (60, ' Hungary'), (84, ' India'), (70, ' Iran'), (60, ' Ireland'), (80, ' Italy'), (70, ' Jamaica'), (99, ' Japan'), (50, ' Laos'), (99, ' Mexico'), (60, ' Nicaragua'), (60, ' Outlying-US(Guam-USVI-etc)'), (60, ' Peru'), (99, ' Philippines'), (65, ' Poland'), (84, ' Portugal'), (80, ' Puerto-Rico'), (60, ' Scotland'), (99, ' South'), (84, ' Taiwan'), (80, ' Thailand'), (60, ' Trinadad&Tobago'), (99, ' United-States'), (77, ' Vietnam'), (66, ' Yugoslavia')]
# [(946613, ' ?'),
#  (19529, ' Cambodia'),
#  (182000, ' Canada'),
#  (27486, ' China'),
#  (10656, ' Columbia'),
#  (34887, ' Cuba'),
#  (103324, ' Dominican-Republic'),
#  (14773, ' Ecuador'),
# ...
